# %% [markdown]
# # Resumir epítopos por antígeno
#
# Dada uma lista de IDs pubmed, use o IQ-API para obter todas as informações de antígenos e epítopos
# e resumir da seguinte forma:
#
# * antígeno_id, nome, etc.
# * número de referências que relatam epítopos positivos derivados desse antígeno
# * num_peptídeos_positivos totais derivados de cada antígeno (cada peptídeo é contado apenas uma vez, mesmo que apareça em múltiplas referências)
#
# fonte:  https://github.com/IEDB/IQ-API-use-cases/tree/master/python
#
# API: https://query-api.iedb.org/docs/swagger/
#
# https://help.iedb.org/hc/en-us/articles/4402872882189-Immune-Epitope-Database-Query-API-IQ-API

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import io
import time
import requests
import pandas as pd

# %%
# Read in the pubmed IDs from a file:
with open('pubmed_ids.txt') as f:
    pubmed_ids = [i.rstrip() for i in f.readlines()]
    pubmed_id_string = ','.join(pubmed_ids)

# %% [markdown]
# Vamos definir uma função para executar uma consulta e retornar um dataframe de resultados. Como pode haver mais de 10 mil registros, precisaremos buscar uma página por vez e continuar a anexá-los ao nosso dataframe.
#
# **NOTA:** Ao paginar os resultados usando um 'offset', é fundamental adicionar um parâmetro 'order' para garantir que as páginas sejam consistentes entre as consultas.
#
# Para sermos bons cidadãos, também adicionamos um breve “sono” entre as chamadas à API.

# %%
def iq_query(endpoint, query_params, base_uri='https://query-api.iedb.org/'):

    url = os.path.join(base_uri, endpoint)
    df = pd.DataFrame()
    
    # set the offset to 0
    query_params['offset'] = 0
    
    # loop through the pages of results
    # API only allows pulling 10,000 entries at a time
    while(True):
        print('Fetching offset: %i' % query_params['offset'])
        r = requests.get(url, params=query_params, headers={'accept': 'text/csv', 'Prefer': 'count=exact'})
        try:
            df = pd.concat([df, pd.read_csv(io.StringIO(r.content.decode('utf-8')))])
            query_params['offset'] += 10000
        except pd.errors.EmptyDataError:
            break
        
        # sleep for 1 second between calls so as not to overload the server
        time.sleep(1)
    
    return df

# %% [markdown]
# ### Mapear IDs publicados para IDs de referência
#
# Vamos definir os parâmetros da string de consulta

# %%
query_params = {'pubmed_id': 'in.(%s)' % pubmed_id_string,
                'order': 'pubmed_id',
                'select': 'pubmed_id,reference_id'}

# %% [markdown]
# Extrair os dados e criar uma string de ID de referência para incorporar em consultas downstream:

# %%
ref2pmid = iq_query('reference_search', query_params)
ref_id_string = ','.join(list(ref2pmid['reference_id'].astype(str)))
# Out:
# Fetching offset: 0
# Fetching offset: 10000

# %% [markdown]
# ### Buscar os epítopos positivos das células T e B
# Primeiro, definir os parâmetros de consulta:

# %%
query_params = {'reference_id': 'in.(%s)' % ref_id_string,
                'qualitative_measure': 'neq.Negative',
                'order': 'pubmed_id',
                'select': 'reference_id,parent_source_antigen_iri,structure_id,structure_description,curated_source_antigen'}

# %% [markdown]
# Agora executar a consulta por epítopos em células T:

# %%
tcell_epitopes = iq_query('tcell_search', query_params)
# Out:
# Fetching offset: 0
# Fetching offset: 10000

# %% [markdown]
# E agora busca por epítopos em células B:

# %%
bcell_epitopes = iq_query('bcell_search', query_params)
# Out:
# Fetching offset: 0
# Fetching offset: 10000

# %% [markdown]
# **NOTA** Há certos casos em que o antígeno de origem é desconhecido/nulo. Vamos quantificar
# aqueles aqui, mas ignoraremos esses epítopos para o restante desta análise.
#
# ### Resumo inicial
#
# Aqui resumimos o número de epítopos de células T e B recuperados e o número em que o antígeno fonte (proteína parental) não é nulo. Avançamos combinando esses dados.

# %%
# "~" operator is NOT; remove epitopes without a source antigen
tcell_epitopes = tcell_epitopes[~tcell_epitopes['parent_source_antigen_iri'].isna()]
bcell_epitopes = bcell_epitopes[~bcell_epitopes['parent_source_antigen_iri'].isna()]

# %% [markdown]
# Em ambos os casos, mais ainda nas células B, há muitos registros que não são mapeados para uma proteína parental. Investigaremos abaixo.
#
# Vamos combinar todos os epítopos em um dataframe.

# %%
all_epitopes = pd.concat([tcell_epitopes, bcell_epitopes])

# %% [markdown]
# ### Referências e peptídeos por antígeno parental
#
# Vamos primeiro obter o número de referências e peptídeos (incluindo sequências descontínuas) por antígeno parental para cada antígeno parental.

# %%
ref_data  = []
peps_data = []
for i, row in all_epitopes.groupby('parent_source_antigen_iri'):
    ref_data.append([i, len(row['reference_id'].unique())])
    peps_data.append([i, len(row['structure_id'].unique())])

refs_per_parent_antigen = pd.DataFrame(data=ref_data, columns=['parent_source_antigen_iri', 'num_references'])
peps_per_parent_antigen = pd.DataFrame(data=peps_data, columns=['parent_source_antigen_iri', 'num_peptides'])

# %%
refs_per_parent_antigen
# Out:
#    parent_source_antigen_iri  num_references
# 0         UNIPROT:A0A0U1RQC9               1
# 1             UNIPROT:A2JGV3               2
# 2             UNIPROT:A5PLL7               3
# 3             UNIPROT:B4DTR1               1
# 4             UNIPROT:D6RHG4               1
# 5             UNIPROT:H0YKS8               1
# 6             UNIPROT:H3BLT4               1
# 7             UNIPROT:I3L0A0               1
# 8             UNIPROT:O14746               1
# 9             UNIPROT:O15438               2
# 10            UNIPROT:O15466               1
# 11            UNIPROT:O42043               1
# 12            UNIPROT:O75638               1
# 13            UNIPROT:P00533               2
# 14            UNIPROT:P02782               1
# 15            UNIPROT:P04626               2
# 16            UNIPROT:P06239               3
# 17            UNIPROT:P06731               1
# 18            UNIPROT:P07288               5
# 19            UNIPROT:P08183               1
# 20            UNIPROT:P0DTU4               1
# 21            UNIPROT:P10415               1
# 22            UNIPROT:P12272               2
# 23            UNIPROT:P14866               3
# 24            UNIPROT:P15309               3
# 25            UNIPROT:P20151               2
# 26            UNIPROT:P22732               1
# 27            UNIPROT:P23284               3
# 28            UNIPROT:P24385               1
# 29            UNIPROT:P43356               1
# 30            UNIPROT:P60484               1
# 31            UNIPROT:P62684               1
# 32            UNIPROT:P63145               1
# 33            UNIPROT:P70424               1
# 34            UNIPROT:P78358               1
# 35            UNIPROT:Q04609               3
# 36            UNIPROT:Q13541               1
# 37            UNIPROT:Q15020               4
# 38            UNIPROT:Q15910               1
# 39            UNIPROT:Q16655               1
# 40            UNIPROT:Q96JT2               1
# 41            UNIPROT:Q9BZD4               1
# 42            UNIPROT:Q9H3P2               3
# 43            UNIPROT:Q9N2K0               1
# 44            UNIPROT:Q9NRP7               1
# 45            UNIPROT:Q9UL01               1
# 46            UNIPROT:Q9UQF0               1
# 47            UNIPROT:Q9Y3S1               2
# 48            UNIPROT:Q9Y572               1
# 49     taxon_protein:9606-ab               1
# 50  taxon_protein:9606-other               1

# %% [markdown]
# ### Dados de antígeno de origem (proteína mãe)
#
# Antes de juntarmos tudo, precisamos extrair todas as informações do antígeno de origem. Como parent_source_antigen_iri ainda não está na tabela parent_proteins, primeiro extraímos TODAS as proteínas-mãe
# e crie parent_source_antigen_uri mais tarde.

# %%
query_params = {'order': 'accession',
                'select': 'database,accession,name,title,proteome_label'}

# %% [markdown]
# Agora executar a consulta em parent_proteins para extrair tudo

# %%
parent_proteins = iq_query('parent_proteins', query_params)
# Out:
# Fetching offset: 0
# Fetching offset: 10000
# Fetching offset: 20000
# Fetching offset: 30000
# Fetching offset: 40000
# Fetching offset: 50000
# Fetching offset: 60000
# Fetching offset: 70000
# Fetching offset: 80000
# Fetching offset: 90000
# Fetching offset: 100000
# Fetching offset: 110000

# %%
# vamos adicionar um pseudo parent_source_antigen_iri
parent_proteins['parent_source_antigen_iri'] = parent_proteins['database'].str.upper() + ':' + parent_proteins['accession'].str[:]

# %% [markdown]
# ### Resumo final por proteína pai
#
# Aqui, combinamos os dados na tabela de interesse

# %%
final_summary_by_parent = pd.merge(refs_per_parent_antigen, peps_per_parent_antigen, how='left', on='parent_source_antigen_iri')
final_summary_by_parent = pd.merge(final_summary_by_parent, parent_proteins, how='left', on='parent_source_antigen_iri')

# renomear colunas
final_summary_by_parent.rename(columns={'parent_source_antigen_iri': 'antigen_id',
                                        'title': 'antigen_title'}, inplace=True)

# ordenar pelo número de referências e número de peptídeos
final_summary_by_parent = final_summary_by_parent.sort_values('num_references', ascending=False)
final_summary_by_parent = final_summary_by_parent.sort_values('num_peptides', ascending=False)

final_summary_by_parent
# Out:
#                   antigen_id  num_references  num_peptides database  \
# 18            UNIPROT:P07288               5             8  UniProt
# 22            UNIPROT:P12272               2             8  UniProt
# 37            UNIPROT:Q15020               4             8  UniProt
# 16            UNIPROT:P06239               3             7  UniProt
# 26            UNIPROT:P22732               1             7  UniProt
# 32            UNIPROT:P63145               1             6  UniProt
# 31            UNIPROT:P62684               1             6  UniProt
# 35            UNIPROT:Q04609               3             5  UniProt
# 30            UNIPROT:P60484               1             5  UniProt
# 24            UNIPROT:P15309               3             4  UniProt
# 14            UNIPROT:P02782               1             4  UniProt
# 40            UNIPROT:Q96JT2               1             3  UniProt
# 5             UNIPROT:H0YKS8               1             3  UniProt
# 4             UNIPROT:D6RHG4               1             3  UniProt
# 12            UNIPROT:O75638               1             3  UniProt
# 34            UNIPROT:P78358               1             3  UniProt
# 2             UNIPROT:A5PLL7               3             3  UniProt
# 47            UNIPROT:Q9Y3S1               2             2  UniProt
# 1             UNIPROT:A2JGV3               2             2  UniProt
# 27            UNIPROT:P23284               3             2  UniProt
# 3             UNIPROT:B4DTR1               1             2  UniProt
# 11            UNIPROT:O42043               1             2  UniProt
# 23            UNIPROT:P14866               3             2  UniProt
# 10            UNIPROT:O15466               1             2  UniProt
# 42            UNIPROT:Q9H3P2               3             2  UniProt
# 45            UNIPROT:Q9UL01               1             2  UniProt
# 43            UNIPROT:Q9N2K0               1             2  UniProt
# 15            UNIPROT:P04626               2             2  UniProt
# 9             UNIPROT:O15438               2             2  UniProt
# 46            UNIPROT:Q9UQF0               1             2  UniProt
# 19            UNIPROT:P08183               1             2  UniProt
# 6             UNIPROT:H3BLT4               1             2  UniProt
# 29            UNIPROT:P43356               1             1  UniProt
# 28            UNIPROT:P24385               1             1  UniProt
# 17            UNIPROT:P06731               1             1  UniProt
# 20            UNIPROT:P0DTU4               1             1  UniProt
# 8             UNIPROT:O14746               1             1  UniProt
# 21            UNIPROT:P10415               1             1  UniProt
# 36            UNIPROT:Q13541               1             1  UniProt
# 7             UNIPROT:I3L0A0               1             1  UniProt
# 0         UNIPROT:A0A0U1RQC9               1             1  UniProt
# 41            UNIPROT:Q9BZD4               1             1  UniProt
# 39            UNIPROT:Q16655               1             1  UniProt
# 38            UNIPROT:Q15910               1             1  UniProt
# 44            UNIPROT:Q9NRP7               1             1  UniProt
# 48            UNIPROT:Q9Y572               1             1  UniProt
# 49     taxon_protein:9606-ab               1             1      NaN
# 33            UNIPROT:P70424               1             1  UniProt
# 13            UNIPROT:P00533               2             1  UniProt
# 25            UNIPROT:P20151               2             1  UniProt
# 50  taxon_protein:9606-other               1             1      NaN
#
#      accession                            name  \
# 18      P07288            sp|P07288|KLK3_HUMAN
# 22      P12272            sp|P12272|PTHR_HUMAN
# 37      Q15020           sp|Q15020|SART3_HUMAN
# 16      P06239             sp|P06239|LCK_HUMAN
# 26      P22732            sp|P22732|GTR5_HUMAN
# 32      P63145           sp|P63145|GAK24_HUMAN
# 31      P62684           sp|P62684|GA113_HUMAN
# 35      Q04609           sp|Q04609|FOLH1_HUMAN
# 30      P60484            sp|P60484|PTEN_HUMAN
# 24      P15309            sp|P15309|PPAP_HUMAN
# 14      P02782              sp|P02782|PSC1_RAT
# 40      Q96JT2           sp|Q96JT2|S45A3_HUMAN
# 5       H0YKS8          tr|H0YKS8|H0YKS8_HUMAN
# 4       D6RHG4          tr|D6RHG4|D6RHG4_HUMAN
# 12      O75638           sp|O75638|CTAG2_HUMAN
# 34      P78358           sp|P78358|CTG1B_HUMAN
# 2       A5PLL7           sp|A5PLL7|PDES1_HUMAN
# 47      Q9Y3S1            sp|Q9Y3S1|WNK2_HUMAN
# 1       A2JGV3            sp|A2JGV3|TARP_HUMAN
# 27      P23284            sp|P23284|PPIB_HUMAN
# 3       B4DTR1          tr|B4DTR1|B4DTR1_HUMAN
# 11      O42043           sp|O42043|ENK18_HUMAN
# 23      P14866           sp|P14866|HNRPL_HUMAN
# 10      O15466           sp|O15466|SIA8E_HUMAN
# 42      Q9H3P2           sp|Q9H3P2|NELFA_HUMAN
# 45      Q9UL01             sp|Q9UL01|DSE_HUMAN
# 43      Q9N2K0            sp|Q9N2K0|ENH1_HUMAN
# 15      P04626           sp|P04626|ERBB2_HUMAN
# 9       O15438            sp|O15438|MRP3_HUMAN
# 46      Q9UQF0           sp|Q9UQF0|SYCY1_HUMAN
# 19      P08183            sp|P08183|MDR1_HUMAN
# 6       H3BLT4          tr|H3BLT4|H3BLT4_HUMAN
# 29      P43356           sp|P43356|MAGA2_HUMAN
# 28      P24385           sp|P24385|CCND1_HUMAN
# 17      P06731           sp|P06731|CEAM5_HUMAN
# 20      P0DTU4           sp|P0DTU4|TRBR2_HUMAN
# 8       O14746            sp|O14746|TERT_HUMAN
# 21      P10415            sp|P10415|BCL2_HUMAN
# 36      Q13541           sp|Q13541|4EBP1_HUMAN
# 7       I3L0A0          tr|I3L0A0|I3L0A0_HUMAN
# 0   A0A0U1RQC9  tr|A0A0U1RQC9|A0A0U1RQC9_HUMAN
# 41      Q9BZD4            sp|Q9BZD4|NUF2_HUMAN
# 39      Q16655            sp|Q16655|MAR1_HUMAN
# 38      Q15910            sp|Q15910|EZH2_HUMAN
# 44      Q9NRP7           sp|Q9NRP7|STK36_HUMAN
# 48      Q9Y572           sp|Q9Y572|RIPK3_HUMAN
# 49         NaN                             NaN
# 33      P70424           sp|P70424|ERBB2_MOUSE
# 13      P00533            sp|P00533|EGFR_HUMAN
# 25      P20151            sp|P20151|KLK2_HUMAN
# 50         NaN                             NaN
#
#                                         antigen_title  \
# 18                          Prostate-specific antigen
# 22                Parathyroid hormone-related protein
# 37  Squamous cell carcinoma antigen recognized by ...
# 16                        Tyrosine-protein kinase Lck
# 26  Solute carrier family 2, facilitated glucose t...
# 32  Endogenous retrovirus group K member 24 Gag po...
# 31  Endogenous retrovirus group K member 113 Gag p...
# 35                       Glutamate carboxypeptidase 2
# 30  Phosphatidylinositol 3,4,5-trisphosphate 3-pho...
# 24                         Prostatic acid phosphatase
# 14               Prostatic steroid-binding protein C1
# 40                  Solute carrier family 45 member 3
# 5   Milk fat globule EGF and factor V/VIII domain ...
# 4                                          Heparanase
# 12                            Cancer/testis antigen 2
# 34                            Cancer/testis antigen 1
# 2                  Plasmanylethanolamine desaturase 1
# 47               Serine/threonine-protein kinase WNK2
# 1   T-cell receptor gamma alternate reading frame ...
# 27              Peptidyl-prolyl cis-trans isomerase B
# 3                   Erb-b2 receptor tyrosine kinase 2
# 11  Endogenous retrovirus group K member 18 Env po...
# 23          Heterogeneous nuclear ribonucleoprotein L
# 10                     Alpha-2,8-sialyltransferase 8E
# 42                       Negative elongation factor A
# 45                         Dermatan-sulfate epimerase
# 43   HERV-H_2q24.3 provirus ancestral Env polyprotein
# 15            Receptor tyrosine-protein kinase erbB-2
# 9          ATP-binding cassette sub-family C member 3
# 46                                         Syncytin-1
# 19                    ATP-dependent translocase ABCB1
# 6                 Baculoviral IAP repeat containing 5
# 29                      Melanoma-associated antigen 2
# 28                            G1/S-specific cyclin-D1
# 17  Carcinoembryonic antigen-related cell adhesion...
# 20                 T cell receptor beta chain MC.7.G5
# 8                    Telomerase reverse transcriptase
# 21                          Apoptosis regulator Bcl-2
# 36  Eukaryotic translation initiation factor 4E-bi...
# 7                                          HCG2044781
# 0                          Cellular tumor antigen p53
# 41                           Kinetochore protein Nuf2
# 39           Melanoma antigen recognized by T-cells 1
# 38            Histone-lysine N-methyltransferase EZH2
# 44                 Serine/threonine-protein kinase 36
# 48  Receptor-interacting serine/threonine-protein ...
# 49                                                NaN
# 33            Receptor tyrosine-protein kinase erbB-2
# 13                   Epidermal growth factor receptor
# 25                                       Kallikrein-2
# 50                                                NaN
#
#                                     proteome_label
# 18                            Homo sapiens (Human)
# 22                            Homo sapiens (Human)
# 37                            Homo sapiens (Human)
# 16                            Homo sapiens (Human)
# 26                            Homo sapiens (Human)
# 32                            Homo sapiens (Human)
# 31                            Homo sapiens (Human)
# 35                            Homo sapiens (Human)
# 30                            Homo sapiens (Human)
# 24                            Homo sapiens (Human)
# 14  Rattus norvegicus (Rat) (Strain: Brown Norway)
# 40                            Homo sapiens (Human)
# 5                             Homo sapiens (Human)
# 4                             Homo sapiens (Human)
# 12                            Homo sapiens (Human)
# 34                            Homo sapiens (Human)
# 2                             Homo sapiens (Human)
# 47                            Homo sapiens (Human)
# 1                             Homo sapiens (Human)
# 27                            Homo sapiens (Human)
# 3                             Homo sapiens (Human)
# 11                            Homo sapiens (Human)
# 23                            Homo sapiens (Human)
# 10                            Homo sapiens (Human)
# 42                            Homo sapiens (Human)
# 45                            Homo sapiens (Human)
# 43                            Homo sapiens (Human)
# 15                            Homo sapiens (Human)
# 9                             Homo sapiens (Human)
# 46                            Homo sapiens (Human)
# 19                            Homo sapiens (Human)
# 6                             Homo sapiens (Human)
# 29                            Homo sapiens (Human)
# 28                            Homo sapiens (Human)
# 17                            Homo sapiens (Human)
# 20                            Homo sapiens (Human)
# 8                             Homo sapiens (Human)
# 21                            Homo sapiens (Human)
# 36                            Homo sapiens (Human)
# 7                             Homo sapiens (Human)
# 0                             Homo sapiens (Human)
# 41                            Homo sapiens (Human)
# 39                            Homo sapiens (Human)
# 38                            Homo sapiens (Human)
# 44                            Homo sapiens (Human)
# 48                            Homo sapiens (Human)
# 49                                             NaN
# 33         Mus musculus (Mouse) (Strain: C57BL/6J)
# 13                            Homo sapiens (Human)
# 25                            Homo sapiens (Human)
# 50                                             NaN

# %% [markdown]
# Como podemos ver pela linha com antígeno_id e antígeno_title vazios, há um bom número de proteínas que não estão mapeadas para uma proteína mãe. Então, vamos dar uma olhada nisso, especificamente:

# %%
all_epitopes['curated_antigen_accession'] = all_epitopes['curated_source_antigen'].str.split(',').str[0].str[1:]
all_epitopes[all_epitopes['parent_source_antigen_iri'].isna()]
# Out:
# Empty DataFrame
# Columns: [reference_id, parent_source_antigen_iri, structure_id, structure_description, curated_source_antigen, curated_antigen_accession]
# Index: []

# %% [markdown]
# Interessante! Nenhum deles possui antígenos de origem selecionados, então devemos investigar o porquê e ignorá-los se houver uma boa explicação.
